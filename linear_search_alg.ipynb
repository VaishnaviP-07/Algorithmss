# %% [markdown]
# <a href="https://colab.research.google.com/github/VaishnaviP-07/Algorithmss/blob/main/linear_search_alg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import random
import matplotlib.pyplot as plt
def linear_search(arr, target):
    for i in range(len(arr)):
        if arr[i] == target:
            return i
    return -1
def measure_time(n):
    arr = random.sample(range(1, 100000), n)
    target = random.choice(arr)
    start_time = time.time()
    linear_search(arr, target)
    end_time = time.time()
    return end_time - start_time
n_values = []
time_taken = []
for n in range(1000, 10001, 1000):
    n_values.append(n)
    time_taken.append(measure_time(n))
plt.plot(n_values, time_taken, marker='o')
plt.xlabel('Number of elements (n)')
plt.ylabel('Time taken (seconds)')
plt.title('Linear Search Time vs n')
plt.grid(True)
plt.show()
